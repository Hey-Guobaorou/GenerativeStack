# %% [markdown]
# # **Convolve!**
#
# ### MACHINE INTELLIGENCE IN ARCHITECTURE SYLLABUS
#
# #### LECTURES/WORKSHOPS
# *Monday 12th July - Friday 23rd July 2021 08:00 to 13:00 CST*
#
# #### TEACHING STAFF
# *Dr. Jose Luis García del Castillo y López\
# jgarciadelcasti@gsd.harvard.edu \
# Lecturer in Architectural Technology\
# Lecturer in Architecture\
# Harvard GSD*
#
# *Runjia Tian\
# runjia_tian@gsd.harvard.edu\
# Machine Learning Researcher\
# Harvard GSD*

# %% [markdown]
# #### Section 1. Jupyter Notebook - Coding Made Easy and Free!

# %% [markdown]
# ##### Section 1.1 ***Markdown***
#
# # This is a level 1 heading
#
# ## This is a level 2 heading
#
# This is some plain text that forms a paragraph. Add emphasis via **bold** and __bold__, or *italic* and _italic_.
#
# Paragraphs must be separated by an empty line.
#
# * Sometimes we want to include lists.
# * Which can be bulleted using asterisks.
#
# 1. Lists can also be numbered.
# 2. If we want an ordered list.
#
# [It is possible to include hyperlinks](https://www.example.com)
#
# Inline code uses single backticks: `foo()`, and code blocks use triple backticks:
# ```
# bar()
# ```
# Or can be indented by 4 spaces:
#
#     foo()
#
# And finally, adding images is easy: ![Alt text](https://www.example.com/image.jpg)

# %% [markdown]
# ##### Section 1.2 Code - Python Basics

# %%
print('Hello World!')
# Out:
# Hello World!

# %%
def square(x):
    return x * x

x = 3
y = square(x)

print(f'{x} squared is {y}')
# Out:
# 3 squared is 9

# %%
import math
'''https://docs.python.org/3.7/library/math.html'''

from random import randint

def square_import(x):
    return math.pow(x, 2)

def 勾股定理(a, b):
    return randint(0,100)

a = randint(0,100)
b = randint(0,500)
c = 勾股定理(a, b)

print(f'直角边{a}和直角边{b}构成的直角三角形斜边长度是{c}')
# Out:
# 直角边49和直角边355构成的直角三角形斜边长度是72

# %% [markdown]
# #### Section 2 Tensor

# %%
import torch

print("PyTorch", torch.__version__)
# Out:
# PyTorch 1.7.0

# %%
torch.cuda.is_available()
# Out:
# True

# %%
img = [[255,0,0], [0,255,0], [0,0,255]]
img
# Out:
# [[255, 0, 0], [0, 255, 0], [0, 0, 255]]

# %%
img_tensor = torch.tensor(img)
img_tensor
# Out:
# tensor([[255,   0,   0],
#         [  0, 255,   0],
#         [  0,   0, 255]])

# %%
import matplotlib.pyplot as plt

plt.imshow(img)
plt.axis('off')
plt.show()

# %%
import matplotlib.pyplot as plt

plt.imshow(img, cmap = 'gray')
plt.axis('off')
plt.show()

# %%
img = [[255,0,100], [0,50,175], [0,0,255]]
img = torch.tensor(img)

plt.imshow(img, cmap = 'gray')
plt.axis('off')
plt.show()

# %%
img = torch.rand((3,3))

plt.imshow(img, cmap = 'gray')
plt.axis('off')
plt.show()

# %% [markdown]
# **Random Image Generator**

# %%
m = 180
n = 210

img = torch.rand((m,n))

plt.figure(figsize=(30,20))
plt.imshow(img, cmap = 'gray')
plt.axis('off')
plt.show()

# %%
img = [[255,0,0], [0,255,0], [0,0,255]]
img = torch.tensor(img)
img = img.reshape((1,3,3))

plt.imshow(img, cmap = 'gray')
plt.axis('off')
plt.show()

# %%
img = [
    [[255,0,0], [0,255,0], [0,0,255]],
    [[255,0,0], [0,255,0], [0,0,255]],
    [[255,0,0], [0,255,0], [0,0,255]],]

img = torch.tensor(img)

plt.imshow(img)
plt.axis('off')
plt.show()

# %%
img = torch.rand((3,9))
img = img.reshape((3,3,3))

plt.imshow(img)
plt.axis('off')
plt.show()

# %%
m = 30
n = 90

img = torch.rand((m,n, 3))

plt.figure(figsize=(30,50))
plt.imshow(img, cmap = 'gray')
plt.axis('off')
plt.show()

# %%
m = 300
n = 900

img = torch.rand((m,n, 3))

plt.figure(figsize=(30,50))
plt.imshow(img, cmap = 'gray')
plt.axis('off')
plt.show()

# %% [markdown]
# #### Real Images

# %%
img = plt.imread("asset/exter_library.jpg")

plt.figure(figsize=(5,10))
plt.imshow(img, cmap = 'gray')
plt.axis('off')
plt.show()
